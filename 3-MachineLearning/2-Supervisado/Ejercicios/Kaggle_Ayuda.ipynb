# %% [markdown]
# ## Librerias

# %%
import pandas as pd

import urllib.request
from PIL import Image

# %% [markdown]
# ## Data

# %%
### Para que funcione necesitas bajarte los archivos de datos de Kaggle 
train = pd.read_csv("Dataset/tran.csv")

# %% [markdown]
# ## Data exploration

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         912 non-null    int64
#  1   Company           912 non-null    object
#  2   Product           912 non-null    object
#  3   TypeName          912 non-null    object
#  4   Inches            912 non-null    float64
#  5   ScreenResolution  912 non-null    object
#  6   Cpu               912 non-null    object
#  7   Ram               912 non-null    object
#  8   Memory            912 non-null    object
#  9   Gpu               912 non-null    object
#  10  OpSys             912 non-null    object
#  11  Weight            912 non-null    object
#  12  Price_euros       912 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 92.8+ KB

# %%
train.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0       1223    Dell       Inspiron 5567            Notebook    15.6
# 1         78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 2       1267    Dell              XPS 13  2 in 1 Convertible    13.3
# 3        161    Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 4        922      LG         Gram 14Z970           Ultrabook    14.0
#
#                             ScreenResolution                         Cpu  Ram  \
# 0                          Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
# 1                          Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
# 2           Quad HD+ / Touchscreen 3200x1800   Intel Core i5 7Y54 1.2GHz  8GB
# 3            Full HD / Touchscreen 1920x1080  Intel Core i7 8550U 1.8GHz  8GB
# 4  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 7500U 2.7GHz  8GB
#
#       Memory                     Gpu       OpSys  Weight  Price_euros
# 0  256GB SSD      AMD Radeon R7 M445  Windows 10  2.36kg        889.0
# 1    2TB HDD   Intel HD Graphics 620       No OS   2.2kg        519.0
# 2  256GB SSD   Intel HD Graphics 615  Windows 10  1.24kg       1813.0
# 3  256GB SSD  Intel UHD Graphics 620  Windows 10  1.56kg       1049.0
# 4  512GB SSD   Intel HD Graphics 620  Windows 10  0.98kg       1899.0

# %% [markdown]
# ## Data processing

# %%
train = train[['laptop_ID','Inches','Price_euros']]

# %%
train
# Out:
#      laptop_ID  Inches  Price_euros
# 0         1223    15.6       889.00
# 1           78    15.6       519.00
# 2         1267    13.3      1813.00
# 3          161    15.6      1049.00
# 4          922    14.0      1899.00
# ..         ...     ...          ...
# 907        709    15.6       399.00
# 908        947    13.3      1799.00
# 909        590    15.6      1537.39
# 910       1143    15.6       989.00
# 911        531    17.3       889.00
#
# [912 rows x 3 columns]

# %%
# df.to_csv("Dataset/limpio.csv")

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Pasos que si o si debéis realizar para poder participar en la competición:

# %% [markdown]
# ### 1. Definir X e y

# %%
X = train.drop(['laptop_ID','Price_euros'], axis=1)
y = train['Price_euros'].copy()
X.shape
# Out:
# (912, 1)

# %%
y.shape
# Out:
# (912,)

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_train
# Out:
#      Inches
# 25     14.0
# 84     15.6
# 10     15.6
# 342    15.6
# 890    13.3
# ..      ...
# 106    15.6
# 270    15.6
# 860    14.0
# 435    15.6
# 102    17.3
#
# [729 rows x 1 columns]

# %% [markdown]
# ### 3. Asignar el modelo (vacío) a una variable

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 4. Sacar métricas, valorar el modelo
#
# Recuerda que en la competición se va a evaluar con la métrica de RMSE.

# %%
from sklearn.metrics import root_mean_squared_error

predictions = regressor.predict(X_test)

rmse = root_mean_squared_error(y_test, predictions)

# %%
print(rmse)
# Out:
# 756.144356190001

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir con el dataset de predicción

# %% [markdown]
# Definición de **modelo que está listo**.
#
# Tras hacer suficientes pruebas, analizar los datos, hacer feature engineering, probar diferentes modelos con diferentes parámetros, es con este con el que observo mejores métricas y menos overfitting. ¡Cuidado con el overfitting aquí! Si vuestro modelo aprende muy bien de estos datos pero hay overfitting cuando le pasemos los datos desconocidos de `test.csv` nos arriesgamos a que digamos, no salga lo esperado.

# %% [markdown]
# ### 1. Entrena dicho modelo con TODOS tus datos de train, esto es con `train.csv` al completo.
#
#
# **CON LAS TRANSFORMACIONES QUE LE HAYAS REALIZADO A `X` INCLUÍDAS.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ### 2. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("Dataset/test.csv")
X_pred.head()
# Out:
#    laptop_ID   Company                 Product   TypeName  Inches  \
# 0        539      Asus  Zenbook UX510UW-FI095T   Notebook    15.6
# 1        327      Asus  ZenBook UX410UA-GV183T   Notebook    14.0
# 2        563  Mediacom           SmartBook 130   Notebook    13.3
# 3         13     Apple             MacBook Pro  Ultrabook    15.4
# 4        935        HP           EliteBook 850  Ultrabook    15.6
#
#                      ScreenResolution                          Cpu   Ram  \
# 0     IPS Panel 4K Ultra HD 3840x2160   Intel Core i7 7500U 2.7GHz   8GB
# 1                   Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 2         IPS Panel Full HD 1920x1080  Intel Atom x5-Z8350 1.44GHz   4GB
# 3  IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz  16GB
# 4                   Full HD 1920x1080   Intel Core i7 6500U 2.5GHz   8GB
#
#                  Memory                      Gpu       OpSys  Weight
# 0  256GB SSD +  1TB HDD  Nvidia GeForce GTX 960M  Windows 10     2kg
# 1             256GB SSD    Intel HD Graphics 620  Windows 10     2kg
# 2    32GB Flash Storage        Intel HD Graphics  Windows 10  1.35kg
# 3             256GB SSD       AMD Radeon Pro 555       macOS  1.83kg
# 4             256GB SSD      AMD Radeon R7 M365X  Windows 10  1.84kg

# %%
X_pred.shape
# Out:
# (391, 12)

# %% [markdown]
# **¿Por qué da error?**

# %%
predictions_submit = regressor.predict(X_pred)
predictions_submit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 predictions_submit = regressor.predict(X_pred)
#       2 predictions_submit
#
# File c:\Users\jamr1\Desktop\DS102024\.venv\Lib\site-packages\sklearn\linear_model\_base.py:297, in LinearModel.predict(self, X)
#     283 def predict(self, X):
#     284     """
#     285     Predict using the linear model.
#     286
#    (...)
#     295         Returns predicted values.
#     296     """
# --> 297     return self._decision_function(X)
#
# File c:\Users\jamr1\Desktop\DS102024\.venv\Lib\site-packages\sklearn\linear_model\_base.py:276, in LinearModel._decision_function(self, X)
#     273 def _decision_function(self, X):
#     274     check_is_fitted(self)
# --> 276     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     277     coef_ = self.coef_
#     278     if coef_.ndim == 1:
#
# File c:\Users\jamr1\Desktop\DS102024\.venv\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)
#    2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)
#    2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File c:\Users\jamr1\Desktop\DS102024\.venv\Lib\site-packages\sklearn\utils\validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Company
# - Cpu
# - Gpu
# - Memory
# - OpSys
# - ...

# %% [markdown]
# IMPORTANTE: APLICAR LO MISMO A ESTOS DATOS QUE HAYÁIS APLICADO A LOS DATOS DE ENTRENAMIENTO
#
# - SI EL ARRAY CON EL QUE HICISTEIS `.fit()` ERA DE 4 COLUMNAS, PARA `.predict()` DEBEN SER LAS MISMAS
# - SI AL ARRAY CON EL QUE HICISTEIS `.fit()` LO NORMALIZASTEIS, PARA `.predict()` DEBÉIS NORMALIZARLO
# - TODO IGUAL SALVO BORRAR FILAS, EL NÚMERO DE ROWS SE DEBE MANTENER EN ESTE SET, PUES LA PREDICCIÓN DEBE TENER 391 FILAS, SI O SI

# %% [markdown]
# **Entonces, si al cargar los datos de train usé `index_col=0` para que utilizara la primera columna del conjunto de datos como índice, ¿tendré que hacerlo también para el conjunto `test.csv`?**

# %%
# ¿Qué opináis?
# Sí

# %% [markdown]
# ![](https://www.tierraljelechu.com/web/img/wiki_up/1.996-SorpresaDto.-1-Red.jpg)

# %%
X_pred = pd.read_csv("Dataset/test.csv")
X_pred.head()
# Out:
#    laptop_ID   Company                 Product   TypeName  Inches  \
# 0        539      Asus  Zenbook UX510UW-FI095T   Notebook    15.6
# 1        327      Asus  ZenBook UX410UA-GV183T   Notebook    14.0
# 2        563  Mediacom           SmartBook 130   Notebook    13.3
# 3         13     Apple             MacBook Pro  Ultrabook    15.4
# 4        935        HP           EliteBook 850  Ultrabook    15.6
#
#                      ScreenResolution                          Cpu   Ram  \
# 0     IPS Panel 4K Ultra HD 3840x2160   Intel Core i7 7500U 2.7GHz   8GB
# 1                   Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 2         IPS Panel Full HD 1920x1080  Intel Atom x5-Z8350 1.44GHz   4GB
# 3  IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz  16GB
# 4                   Full HD 1920x1080   Intel Core i7 6500U 2.5GHz   8GB
#
#                  Memory                      Gpu       OpSys  Weight
# 0  256GB SSD +  1TB HDD  Nvidia GeForce GTX 960M  Windows 10     2kg
# 1             256GB SSD    Intel HD Graphics 620  Windows 10     2kg
# 2    32GB Flash Storage        Intel HD Graphics  Windows 10  1.35kg
# 3             256GB SSD       AMD Radeon Pro 555       macOS  1.83kg
# 4             256GB SSD      AMD Radeon R7 M365X  Windows 10  1.84kg

# %%
X_pred = X_pred[['Inches']]
X_pred
# Out:
#      Inches
# 0      15.6
# 1      14.0
# 2      13.3
# 3      15.4
# 4      15.6
# ..      ...
# 386    13.3
# 387    13.3
# 388    15.6
# 389    14.0
# 390    15.6
#
# [391 rows x 1 columns]

# %% [markdown]
# ### 3. AHORA puedo hacer la predicción que será lo que subirás a Kaggle.

# %% [markdown]
# **¿Qué es lo que subirás a Kaggle?**

# %%
predictions_submit = regressor.predict(X_pred)
predictions_submit
# Out:
# array([1121.40247869, 1098.40295269, 1088.34066007, 1118.52753794,
#        1121.40247869, 1121.40247869, 1145.83947506, 1121.40247869,
#        1121.40247869, 1098.40295269, 1121.40247869, 1098.40295269,
#        1121.40247869, 1121.40247869, 1145.83947506, 1145.83947506,
#        1063.9036637 , 1121.40247869, 1121.40247869, 1121.40247869,
#        1145.83947506, 1088.34066007, 1145.83947506, 1121.40247869,
#        1088.34066007, 1121.40247869, 1121.40247869, 1121.40247869,
#        1098.40295269, 1145.83947506, 1096.96548232, 1088.34066007,
#        1121.40247869, 1088.34066007, 1121.40247869, 1098.40295269,
#        1145.83947506, 1145.83947506, 1121.40247869, 1098.40295269,
#        1121.40247869, 1098.40295269, 1091.21560082, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1145.83947506,
#        1121.40247869, 1098.40295269, 1121.40247869, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1098.40295269,
#        1145.83947506, 1145.83947506, 1145.83947506, 1098.40295269,
#        1145.83947506, 1121.40247869, 1121.40247869, 1121.40247869,
#        1098.40295269, 1145.83947506, 1121.40247869, 1069.6535452 ,
#        1121.40247869, 1063.9036637 , 1042.34160808, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1145.83947506,
#        1088.34066007, 1145.83947506, 1121.40247869, 1121.40247869,
#        1145.83947506, 1121.40247869, 1121.40247869, 1121.40247869,
#        1121.40247869, 1076.84089707, 1145.83947506, 1098.40295269,
#        1121.40247869, 1121.40247869, 1121.40247869, 1088.34066007,
#        1121.40247869, 1118.52753794, 1121.40247869, 1145.83947506,
#        1088.34066007, 1121.40247869, 1145.83947506, 1121.40247869,
#        1121.40247869, 1121.40247869, 1145.83947506, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1145.83947506,
#        1098.40295269, 1098.40295269, 1145.83947506, 1098.40295269,
#        1145.83947506, 1145.83947506, 1121.40247869, 1098.40295269,
#        1098.40295269, 1121.40247869, 1098.40295269, 1088.34066007,
#        1145.83947506, 1098.40295269, 1121.40247869, 1098.40295269,
#        1098.40295269, 1098.40295269, 1076.84089707, 1145.83947506,
#        1121.40247869, 1121.40247869, 1121.40247869, 1121.40247869,
#        1121.40247869, 1088.34066007, 1088.34066007, 1121.40247869,
#        1145.83947506, 1145.83947506, 1121.40247869, 1121.40247869,
#        1098.40295269, 1088.34066007, 1121.40247869, 1098.40295269,
#        1121.40247869, 1145.83947506, 1121.40247869, 1145.83947506,
#        1145.83947506, 1121.40247869, 1096.96548232, 1098.40295269,
#        1098.40295269, 1121.40247869, 1121.40247869, 1121.40247869,
#        1088.34066007, 1098.40295269, 1145.83947506, 1121.40247869,
#        1088.34066007, 1121.40247869, 1088.34066007, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1088.34066007,
#        1121.40247869, 1121.40247869, 1121.40247869, 1121.40247869,
#        1145.83947506, 1088.34066007, 1145.83947506, 1121.40247869,
#        1145.83947506, 1098.40295269, 1098.40295269, 1121.40247869,
#        1121.40247869, 1088.34066007, 1088.34066007, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1098.40295269,
#        1112.77765644, 1088.34066007, 1098.40295269, 1088.34066007,
#        1121.40247869, 1091.21560082, 1145.83947506, 1088.34066007,
#        1076.84089707, 1145.83947506, 1121.40247869, 1121.40247869,
#        1145.83947506, 1121.40247869, 1145.83947506, 1088.34066007,
#        1088.34066007, 1121.40247869, 1088.34066007, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1121.40247869,
#        1145.83947506, 1145.83947506, 1121.40247869, 1121.40247869,
#        1076.84089707, 1121.40247869, 1121.40247869, 1088.34066007,
#        1121.40247869, 1098.40295269, 1121.40247869, 1121.40247869,
#        1121.40247869, 1121.40247869, 1098.40295269, 1121.40247869,
#        1145.83947506, 1145.83947506, 1088.34066007, 1121.40247869,
#        1088.34066007, 1121.40247869, 1088.34066007, 1121.40247869,
#        1088.34066007, 1121.40247869, 1121.40247869, 1088.34066007,
#        1098.40295269, 1088.34066007, 1121.40247869, 1098.40295269,
#        1145.83947506, 1121.40247869, 1121.40247869, 1121.40247869,
#        1121.40247869, 1076.84089707, 1145.83947506, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1112.77765644,
#        1088.34066007, 1121.40247869, 1121.40247869, 1121.40247869,
#        1121.40247869, 1098.40295269, 1098.40295269, 1121.40247869,
#        1121.40247869, 1121.40247869, 1145.83947506, 1121.40247869,
#        1076.84089707, 1121.40247869, 1088.34066007, 1098.40295269,
#        1145.83947506, 1121.40247869, 1121.40247869, 1121.40247869,
#        1145.83947506, 1121.40247869, 1098.40295269, 1121.40247869,
#        1076.84089707, 1088.34066007, 1088.34066007, 1121.40247869,
#        1121.40247869, 1063.9036637 , 1121.40247869, 1121.40247869,
#        1121.40247869, 1063.9036637 , 1121.40247869, 1121.40247869,
#        1098.40295269, 1088.34066007, 1088.34066007, 1098.40295269,
#        1121.40247869, 1121.40247869, 1145.83947506, 1063.9036637 ,
#        1098.40295269, 1063.9036637 , 1088.34066007, 1076.84089707,
#        1145.83947506, 1121.40247869, 1121.40247869, 1145.83947506,
#        1088.34066007, 1121.40247869, 1121.40247869, 1121.40247869,
#        1121.40247869, 1098.40295269, 1121.40247869, 1088.34066007,
#        1098.40295269, 1121.40247869, 1121.40247869, 1121.40247869,
#        1145.83947506, 1121.40247869, 1121.40247869, 1098.40295269,
#        1121.40247869, 1145.83947506, 1088.34066007, 1088.34066007,
#        1088.34066007, 1121.40247869, 1098.40295269, 1121.40247869,
#        1121.40247869, 1121.40247869, 1121.40247869, 1098.40295269,
#        1073.96595632, 1098.40295269, 1121.40247869, 1088.34066007,
#        1121.40247869, 1088.34066007, 1076.84089707, 1121.40247869,
#        1121.40247869, 1098.40295269, 1121.40247869, 1121.40247869,
#        1121.40247869, 1121.40247869, 1098.40295269, 1121.40247869,
#        1088.34066007, 1145.83947506, 1088.34066007, 1121.40247869,
#        1121.40247869, 1121.40247869, 1145.83947506, 1088.34066007,
#        1121.40247869, 1121.40247869, 1121.40247869, 1088.34066007,
#        1145.83947506, 1121.40247869, 1121.40247869, 1145.83947506,
#        1145.83947506, 1076.84089707, 1121.40247869, 1121.40247869,
#        1121.40247869, 1145.83947506, 1145.83947506, 1145.83947506,
#        1121.40247869, 1088.34066007, 1145.83947506, 1121.40247869,
#        1121.40247869, 1121.40247869, 1088.34066007, 1088.34066007,
#        1121.40247869, 1098.40295269, 1121.40247869])

# %% [markdown]
# **¡PERO! Para subir a Kaggle la predicción, ésta tendrá que tener una forma específica y no valdrá otra.**
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
sample = pd.read_csv("Dataset/sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_euros
# 0        539          650
# 1        327          650
# 2        563          650
# 3         13          650
# 4        935          500

# %%
sample.shape
# Out:
# (391, 2)

# %% [markdown]
# ### 4. Mete tus predicciones en un dataframe.
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
submission = pd.DataFrame({"laptop_ID": sample['laptop_ID'], "Price_euros": predictions_submit})

# %%
submission.head()
# Out:
#    laptop_ID  Price_euros
# 0        539  1121.402479
# 1        327  1098.402953
# 2        563  1088.340660
# 3         13  1118.527538
# 4        935  1121.402479

# %%
submission.shape
# Out:
# (391, 2)

# %% [markdown]
# ### 5. Pásale el CHEQUEATOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeator(df_to_submit,version):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit['laptop_ID'].all() == sample['laptop_ID'].all():
                print("You're ready to submit!")
                submission.to_csv(f"submission_{version}.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto de Clara: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `diamonds_test.csv`. Lloro.")

# %%
chequeator(submission,1)
# Out:
# You're ready to submit!
