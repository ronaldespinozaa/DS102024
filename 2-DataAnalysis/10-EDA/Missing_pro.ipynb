# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from missingno import matrix
import missingno as msno

# %% [markdown]
# # Carga de datos

# %%
original = sns.load_dataset('penguins')

original.dropna(thresh=5, inplace=True)

# %%
df = pd.read_parquet('missing.parquet')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7                NaN
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 337  Gentoo     Biscoe             NaN           13.7              214.0
# 338  Gentoo     Biscoe            46.8           14.3              215.0
# 339  Gentoo     Biscoe            50.4           15.7              222.0
# 340  Gentoo     Biscoe            45.2           14.8              212.0
# 341  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3         3450.0  Female
# 4         3650.0    Male
# ..           ...     ...
# 337       4925.0  Female
# 338       4850.0  Female
# 339          NaN    Male
# 340       5200.0  Female
# 341       5400.0    Male
#
# [342 rows x 7 columns]

# %%
plt.figure(figsize=(16,6))
msno.matrix(df)
plt.title('Patrón de Datos Faltantes')
plt.show();

# %%
plt.figure(figsize=(5,3))
msno.heatmap(df)
plt.title('Correlación de Datos Faltantes')
plt.show();

# %% [markdown]
# # Columna `body_mass_g` MCAR

# %%
print("Análisis de body_mass_g")
print('Meida de datos con missing', original['body_mass_g'].mean())
print('Media con datos faltantes:',
      df['body_mass_g'].dropna().mean())
# Out:
# Análisis de body_mass_g
# Meida de datos con missing 4201.754385964912
# Media con datos faltantes: 4179.568106312292

# %% [markdown]
# # Columna `flipper_length_mm` MAR

# %%
print(df.groupby('species')['flipper_length_mm'].apply(lambda x: x.isna().mean() * 100))
# Out:
# species
# Adelie       23.84106
# Chinstrap     0.00000
# Gentoo        0.00000
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# # Columna `bill_length_mm` MNAR

# %%
print(original['bill_length_mm'].mean())
print('Media de bill_length_mm con datos faltantes',
      df['bill_length_mm'].mean())
# Out:
# 43.9219298245614
# Media de bill_length_mm con datos faltantes 42.80072727272727

# %% [markdown]
# # Tratamientos

# %%
# 1. Tratamiento MCAR
# Podemos usar imputación simple
body_mass_imputed = df['body_mass_g'].fillna(
    df['body_mass_g'].mean())

# 2. Tratamiento MAR
# Usamos imputación por grupos
flipper_imputed = df.groupby('species')['flipper_length_mm'].transform(
    lambda x: x.fillna(x.mean()))


# 3. Tratamiento MNAR
# Aquí necesitaríamos métodos más sofisticados, pero podemos mostrar un ejemplo simple

from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
bill_length_imputed = imputer.fit_transform(
    df[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm']])[:, 0]
